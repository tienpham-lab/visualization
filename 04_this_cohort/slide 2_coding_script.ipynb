# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import plotly
import requests

# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests
